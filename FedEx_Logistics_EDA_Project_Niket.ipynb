# %% [markdown]
# # ***Project Name*** - FeDex Logistics EDA

# %% [markdown]
# ![Screenshot (282).png](attachment:0f870380-d688-4208-a0e2-8b1fa46faca8.png)

# %% [markdown]
# # Project Type - EDA

# %% [markdown]
# # Project Summary -
#
# This project focuses on performing Exploratory Data Analysis (EDA) on a FedEx logistics dataset, aiming to uncover insights and optimize logistics processes. The dataset consists of 10,324 entries and 33 columns, containing detailed shipment, product, and logistics information such as project codes, shipment modes, product descriptions, freight costs, and delivery dates. Key columns include shipment-related details like Shipment Mode, Scheduled Delivery Date, and Freight Cost (USD), along with product-specific information such as Brand, Dosage, and Item Description.
#
# EDA steps in this project include cleaning the data by handling missing values, converting incorrect data types, and managing outliers. Data visualization techniques are applied to identify patterns and correlations between different attributes, especially focusing on shipment costs, product types, and delivery performance. Descriptive statistics are used to summarize the key metrics, while deeper exploratory analysis helps identify areas for improvement in the logistics and supply chain process. The project uses tools like Pandas for data manipulation, Matplotlib and Seaborn for visualization, and Jupyter Notebook for analysis documentation. Insights gained from the analysis can potentially lead to improved decision-making and cost optimization in logistics operations.

# %% [markdown]
# # Problem Statement
#
# The problem statement for this project is to perform Exploratory Data Analysis (EDA) on a FedEx logistics dataset to identify patterns, trends, and insights that can optimize logistics processes and improve decision-making. The dataset contains information on over 10,000 shipments, including shipment details, product descriptions, freight costs, delivery dates, and more. The goal is to analyze the relationships between various attributes such as shipment modes, delivery performance, product types, and associated costs. The project aims to:
#
# 1. Clean the dataset by handling missing values, correcting data types, and addressing any inconsistencies.
# 2. Explore and visualize key metrics such as shipment costs, delivery times, and product characteristics.
# 3. Identify factors that impact freight costs, delivery delays, and shipment efficiency.
# 4. Provide actionable insights and recommendations for optimizing FedEx’s logistics operations, such as cost reduction strategies,
#   improvements in shipment scheduling, and enhancements in product categorization.
#
# By conducting thorough EDA, the project seeks to uncover valuable insights that can help FedEx enhance their logistics strategy, streamline operations, and ultimately deliver more efficient and cost-effective services to their clients.
# its clients.

# %% [markdown]
# ## Define Your Business Objective?
#
# The business objective of this project is to leverage data-driven insights to optimize the logistics operations of FedEx, focusing on improving efficiency, reducing costs, and enhancing customer satisfaction. By performing Exploratory Data Analysis (EDA) on the logistics dataset, the aim is to:
#
# 1. **Optimize Freight Costs**: Identify patterns and factors that influence freight costs to develop strategies for reducing shipping expenses while maintaining service quality.
#
# 2. **Enhance Delivery Efficiency**: Analyze delivery timelines and factors contributing to delays, enabling improvements in shipment scheduling, route optimization, and resource allocation to ensure timely deliveries.
#
# 3. **Improve Product Categorization**: Explore how product classifications and descriptions impact logistics processes, leading to better inventory management and streamlined handling of shipments.
#
# 4. **Identify Operational Bottlenecks**: Pinpoint areas of inefficiency or inconsistencies in the logistics chain, allowing for process improvements that increase operational productivity.
#
# 5. **Support Data-Driven Decision Making**: Provide actionable insights to decision-makers, enabling them to make informed choices that optimize logistics operations, reduce costs, and improve overall service quality.
#
# Ultimately, the business objective is to transform data into valuable insights that lead to more cost-effective, efficient, and reliable logistics solutions, benefiting both FedEx and its clients.

# %% [markdown]
# # ***General Guidelines : -***
#
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # **1. Know Your Data**

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
from sklearn.preprocessing import StandardScaler
from scipy import stats
import plotly.express as px
import plotly.io as pio

# %%
# Suppress all warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load Dataset
df = pd.read_csv("SCMS_Delivery_History_Dataset.csv")
df.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# ...

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (10324, 33)

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
#  11  PO Sent to Vendor Date        10324 non-null  object
# ...

# %%
# Count of Duplicate Value
df.duplicated().sum()
# Out:
# 0

# %%
#  Checking Missing Values/Null Values Count
df.isnull().sum()
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                    360
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# ...

# %% [markdown]
# # What did you know about your dataset?
#
# The dataset is a detailed FedEx logistics dataset with 10,324 entries and 33 columns. It contains information on shipments, product details, and logistics operations. The data includes both numerical and categorical types, covering shipment processes, product attributes, and costs.
#
# **Key Features:**
# 1. **Shipment Details:**
#    - Columns like `Project Code`, `PQ #`, `PO / SO #`, and `ASN/DN #` provide shipment tracking IDs.
#    - Details about shipment mode (e.g., air, sea, land) and delivery dates (`Scheduled Delivery Date`, `Delivered to Client Date`) are included.
#
# 2. **Product Information:**
#    - Data on product categories (`Product Group`, `Brand`) and descriptions (`Item Description`, `Dosage`).
#    - Information on product size and quantity (`Weight (Kilograms)`, `Unit of Measure (Per Pack)`).
#
# 3. **Costs:**
#    - Shipping costs (`Freight Cost (USD)`, `Line Item Insurance (USD)`).
#    - Pricing details (`Pack Price`, `Unit Price`, `Line Item Value`).
#
# 4. **Missing Data:**
#    - Some columns, like `Shipment Mode`, `Dosage`, `Insurance`, and `Weight`, have missing values that need cleaning.
#
# 5. **Data Types:**
#    - Mix of numerical (`Weight`, `Freight Cost`), categorical (`Country`, `Vendor`), and date-based data (`Scheduled Delivery Date`).
#
# This dataset is essential for analyzing trends, improving processes, and finding insights for better logistics operations.

# %%
# Dataset Columns
df.columns
# Out:
# Index(['ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  ID  Unit of Measure (Per Pack)  Line Item Quantity  \
# count  10324.000000                10324.000000        10324.000000
# mean   51098.968229                   77.990895        18332.534870
# std    31944.332496                   76.579764        40035.302961
# min        1.000000                    1.000000            1.000000
# 25%    12795.750000                   30.000000          408.000000
# 50%    57540.500000                   60.000000         3000.000000
# 75%    83648.250000                   90.000000        17039.750000
# max    86823.000000                 1000.000000       619999.000000
#
#        Line Item Value    Pack Price    Unit Price  Line Item Insurance (USD)
# count     1.032400e+04  10324.000000  10324.000000               10037.000000
# mean      1.576506e+05     21.910241      0.611701                 240.117626
# std       3.452921e+05     45.609223      3.275808                 500.190568
# ...

# %% [markdown]
# # Variables Description
#
# The dataset includes various important variables offering detailed insights into FedEx's logistics operations:
#
# - **ID**: Unique identifier for each shipment.
# - **Project Code**, **PQ #**, **PO / SO #**: Order and project identifiers.
# - **ASN/DN #**: Advanced shipment notice or delivery note number.
# - **Country**: Destination of the shipment.
# - **Managed By**: Person or team responsible for the shipment.
# - **Fulfill Via**: Method of shipment fulfillment.
# - **Vendor INCO Term**: Shipping terms.
# - **Shipment Mode**: Transportation method (air, sea, land).
# - **Dates**: Stages of the shipment process, including PQ sent, PO sent, scheduled delivery, and delivery recorded dates.
#
# **Product Details**:
# - **Product Group**, **Sub Classification**, **Vendor**, **Item Description**, **Molecule/Test Type**, **Brand**: Information about product categories and specifics.
# - **Dosage** and **Dosage Form**: Product dosage details (some missing values).
# - **Unit of Measure (Per Pack)**, **Line Item Quantity**, **Line Item Value**: Shipment size and monetary value.
#
# **Cost and Other Features**:
# - **Pack Price**, **Unit Price**, **Freight Cost (USD)**: Cost details.
# - **Manufacturing Site**, **First Line Designation**: Manufacturing location and classification.
# - **Weight (Kilograms)**, **Line Item Insurance (USD)**: Shipment weight and insurance costs.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# ID                              10324
# Project Code                      142
# PQ #                             1237
# PO / SO #                        6233
# ASN/DN #                         7030
# Country                            43
# Managed By                          4
# Fulfill Via                         2
# Vendor INCO Term                    8
# Shipment Mode                       4
# PQ First Sent to Client Date      765
# PO Sent to Vendor Date            897
# Scheduled Delivery Date          2006
# Delivered to Client Date         2093
# Delivery Recorded Date           2042
# Product Group                       5
# Sub Classification                  6
# Vendor                             73
# Item Description                  184
# Molecule/Test Type                 86
# Brand                              48
# Dosage                             54
# Dosage Form                        17
# Unit of Measure (Per Pack)         31
# Line Item Quantity               5065
# ...

# %% [markdown]
# # **Data Wrangling**

# %%
# Remove specified columns
df = df.drop(columns=['PQ #', 'PO / SO #', 'ASN/DN #', 'PQ First Sent to Client Date', 'PO Sent to Vendor Date'])

# Convert 'Weight (Kilograms)' and 'Freight Cost (USD)' to numeric, handling errors (non-numeric values)
df['Weight (Kilograms)'] = pd.to_numeric(df['Weight (Kilograms)'], errors='coerce')
df['Freight Cost (USD)'] = pd.to_numeric(df['Freight Cost (USD)'], errors='coerce')

# Fill missing values

# For 'Shipment Mode', since it's categorical, use the mode (most frequent value)
shipment_mode_mode = df['Shipment Mode'].mode()[0]
df['Shipment Mode'] = df['Shipment Mode'].fillna(shipment_mode_mode)

# For 'Line Item Insurance (USD)', use the median (since it's a numeric value)
line_item_insurance_median = df['Line Item Insurance (USD)'].median()
df['Line Item Insurance (USD)'] = df['Line Item Insurance (USD)'].fillna(line_item_insurance_median)

# For 'Dosage', if it's categorical, use mode or drop rows if it's not needed
dosage_mode = df['Dosage'].mode()[0] if df['Dosage'].isnull().sum() > 0 else None
if dosage_mode:
    df['Dosage'] = df['Dosage'].fillna(dosage_mode)

# If other columns have missing numeric values, you can fill them with the mean (or median if skewed)
df['Weight (Kilograms)'] = df['Weight (Kilograms)'].fillna(df['Weight (Kilograms)'].mean())
df['Freight Cost (USD)'] = df['Freight Cost (USD)'].fillna(df['Freight Cost (USD)'].mean())

# Round 'Weight (Kilograms)' and 'Freight Cost (USD)' to 2 decimal places
df['Weight (Kilograms)'] = df['Weight (Kilograms)'].round(2)
df['Freight Cost (USD)'] = df['Freight Cost (USD)'].round(2)

# %% [markdown]
# # What manipulations have been done, and what insights found?
#
# ### Data Manipulations and Insights
#
# #### **1. Column Removal:**
# - Removed unnecessary columns like `PQ #`, `PO / SO #`, `ASN/DN #`, `PQ First Sent to Client Date`, and `PO Sent to Vendor Date`. These columns were identifiers or irrelevant for analysis and were excluded to focus on meaningful attributes.
#
# #### **2. Data Type Conversion:**
# - Converted non-numeric columns like `Weight (Kilograms)` and `Freight Cost (USD)` to numeric using `pd.to_numeric()` with `errors='coerce'` to handle invalid entries and transform them into `NaN` values. This ensures proper analysis and mathematical operations.
#
# #### **3. Handling Missing Data:**
# - **Categorical Columns:**
#   - Filled missing values in `Shipment Mode` and `Dosage` with their most frequent value (mode), ensuring consistency.
# - **Numeric Columns:**
#   - Filled missing values in `Line Item Insurance (USD)` with the median to account for skewness.
#   - Used the mean to fill gaps in `Weight (Kilograms)` and `Freight Cost (USD)` for normal distributions.
#
# #### **4. Rounding Values:**
# - Rounded `Weight (Kilograms)` and `Freight Cost (USD)` to two decimal places for standardized formatting and readability.
#
# #### **5. Final Missing Data Check:**
# - Checked for any remaining missing values, ensuring the dataset is complete and ready for further use.
#
# ---
#
# ### Insights
#
# 1. **Improved Data Quality:**
#    - Simplifying the dataset by removing irrelevant columns reduces noise and enhances focus.
#    - Numeric conversions make operations like statistical analysis seamless.
#
# 2. **Effective Missing Data Handling:**
#    - Mode-based imputation ensures categorical consistency.
#    - Median or mean fills ensure minimal impact from missing values in numeric data.
#
# 3. **Data Precision:**
#    - Rounding enhances readability and consistency in financial and weight data.
#
# ---
#
# ### Next Steps
# - Perform statistical analysis and model training using the cleaned dataset.
# - Further analysis could include trend exploration and identifying outliers in key fields like `Weight (Kilograms)` and `Freight Cost (USD)` for logistics insights.
#
# ---

# %% [markdown]
# # *Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables*

# %%
# Distribution of Freight Cost(USD)
plt.figure(figsize=(10, 6))
sns.histplot(df['Freight Cost (USD)'], kde=True, bins=30)
plt.title('Distribution of Freight Cost (USD)')
plt.xlabel('Freight Cost (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### **1. Why was this specific chart chosen?**
# This histogram with a KDE curve was chosen because it effectively visualizes the **distribution** of the freight cost data. It helps:
# - Understand the **frequency of freight costs** across different ranges.
# - Reveal **skewness** or outliers in the data.
# - Aid in deciding whether data transformations are needed for modeling or analysis.
#
# ---
#
# ### **2. What insights are found from the chart?**
#
#  **Key Insights:**
# - The **distribution is highly right-skewed**, meaning:
#   - Most shipments have **low to moderate freight costs**.
#   - A small number of shipments have **extremely high freight costs**, which are clear **outliers**.
#
# - The majority of freight costs seem to lie between **$0 and $25,000**, with a very steep drop-off beyond that.
#
# - There is a **long tail** toward the high-cost end, indicating **a few shipments are significantly more expensive** than the rest.
#
# ---
#
# ### **3. Will the gained insights help create a positive business impact?**
#
#  **Yes, these insights can drive positive business decisions:**
#
# - **Cost Optimization:**
#   By identifying high-cost outliers, the business can:
#   - Investigate whether these costs are justified (e.g., distance, weight, urgency).
#   - Negotiate better rates or optimize logistics for expensive shipments.
#
# - **Forecasting & Budgeting:**
#   Understanding the typical freight cost range helps set **realistic budgets** and **improve cost predictions** for upcoming shipments.
#
# - **Segment Analysis:**
#   The business can **segment** shipments based on cost ranges to identify the most profitable vs. the most expensive (and potentially loss-making) ones.
#
# - **Fraud or Error Detection:**
#   Extreme values might also indicate **data entry errors** or **fraudulent charges** that need to be corrected.
#
# ---
#
# ### **4. Are there any insights that could lead to negative growth? Justify.**
#
#  **Yes, if not addressed, the skewness and high outliers can result in negative consequences:**
#
# - **Misleading Averages:**
#   The **mean freight cost** might be misleading due to the presence of outliers, leading to **wrong assumptions** in financial planning or pricing strategy.
#
# - **Inefficient Resource Allocation:**
#   If high-cost shipments aren't analyzed and optimized, they could **inflate operating expenses** and reduce profit margins.
#
# - **Customer Pricing Issues:**
#   If freight cost is passed to the customer, such high variability can **affect customer satisfaction** and **perceived fairness in pricing**.

# %%
# Relationship between Weight and Freight Cost
# Removed the outlier
df = df[df['ID'] != 3972]

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Weight (Kilograms)'], y=df['Freight Cost (USD)'])
plt.title('Relationship between Weight and Freight Cost')
plt.xlabel('Weight (Kilograms)')
plt.ylabel('Freight Cost (USD)')
plt.show()

# %% [markdown]
# ### **1. Why was this specific chart chosen?**
#
# A **scatter plot** is ideal for analyzing the **relationship between two continuous variables**—in this case, **Weight** and **Freight Cost**. This chart was chosen because:
#
# - It visually shows how changes in weight impact freight cost.
# - It helps detect **correlations**, **clusters**, and **outliers**.
# - It reveals **non-linear relationships** or patterns that might be missed in other chart types like bar or line charts.
#
# ---
#
# ### **2. What insight(s) are found from the chart?**
#
#  **Key Insights:**
#
# - There is **no strong linear correlation** between weight and freight cost:
#   - Some **low-weight items have very high freight costs**.
#   - Some **heavy-weight items have low or moderate freight costs**.
# - A large **concentration of data points** exists in the bottom-left quadrant, where both weight and cost are relatively low.
# - A few **extreme outliers** are present with freight costs exceeding $200,000 or weights beyond 100,000 kg.
#
#  This suggests that **freight cost is influenced by other factors** beyond just weight—such as distance, shipment type (air, sea, road), urgency, or insurance.
#
# ---
#
# ### **3. Will the gained insights help create a positive business impact?**
#
#  **Yes, here’s how the insights can help:**
#
# - **Optimize Pricing Models:**
#   Since weight doesn’t solely determine freight cost, pricing strategies should consider **multi-factor models** (e.g., destination, delivery time, carrier type).
#
# - **Cost Control:**
#   The presence of high-cost shipments for low weights can indicate **inefficiencies or errors** (e.g., expensive courier services, poor packaging, or priority shipping for non-urgent items).
#
# - **Improve Forecasting Accuracy:**
#   Relying solely on weight to predict cost is unreliable. Including other features will yield better **predictive models**, improving **budget planning**.
#
# - **Operational Review:**
#   The outliers should be investigated for potential **cost reduction**—whether through route optimization, vendor negotiation, or bulk shipment options.
#
# ---
#
# ### **Are there any insights that could lead to negative growth? Justify.**
#
#  **Yes, if the insights are ignored, they could lead to negative impacts:**
#
# - **Inefficient Resource Allocation:**
#   Misjudging freight cost based on weight alone may result in **unexpected shipping expenses**, which can erode profit margins.
#
# - **Overpricing or Underpricing Products:**
#   If businesses incorrectly assume that heavier products always cost more to ship, they might price items in a way that either **discourages customers** or **absorbs unnecessary costs**.
#
# - **Missed Optimization Opportunities:**
#   Failure to analyze high-cost, low-weight shipments could mean **missing chances to renegotiate contracts or change carriers**.

# %%
# Shipment Mode vs. Freight Cost
plt.figure(figsize=(10, 6))
sns.barplot(x='Shipment Mode', y='Freight Cost (USD)', data=df, errorbar=None)
plt.title('Average Freight Cost by Shipment Mode')
plt.xlabel('Shipment Mode')
plt.ylabel('Average Freight Cost (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### **1. Why was this chart chosen?**
#
# A **bar chart** is ideal for comparing the **average freight cost** across different **shipment modes**. It clearly shows which modes are more or less expensive.
#
# ---
#
# ### **2. What are the insights from the chart?**
#
# - **Air Charter is the most expensive** – It has the highest average cost.
# - **Truck is the most economical** – It offers the lowest average cost, making it cost-effective.
# - **Air and Ocean are similar** – Their average costs are close, so the choice between them may depend on factors like **speed** or **reliability**, not just cost.
#
# ---
#
# ### **3. Can these insights help create a positive bu  iness impact?**
#
# ✅ **Yes, they can help:**
#
# - **Reduce shipping costs** by choosing cheaper modes.
# - **Make better decisions** by balancing cost with speed and service.
# - **Negotiate better deals** using cost insights for high-volume shipping.
#
# ---
#
# ### **Any risks or poi  ble negative impacts?**
#
# ⚠️ **Yes, if not used carefully:**
#
# - **Focusing only on cost** might ignore important factors like delivery time or reliability.
# - **Outliers** can distort the average cost, leading to wrong conclusions.
# - **Misunderstanding the chart** might lead to poor decisions (e.g., choo into a slide or presentation format!

# %%
# Line Item Quantity vs. Line Item Value
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Line Item Quantity'], y=df['Line Item Value'])
plt.title('Line Item Quantity vs. Line Item Value')
plt.xlabel('Line Item Quantity')
plt.ylabel('Line Item Value (USD)')
plt.show()

# %% [markdown]
# ### **1. Why was this chart chosen?**
#
# A **scatter plot** is ideal for visualizing the **relationship between two continuous variables** – in this case, **Line Item Quantity** and **Line Item Value**. It helps identify trends, patterns, and outliers.
#
# ---
#
# ### **2. What are the insights from the chart?**
#
# -  **Positive Correlation**: As the **quantity increases**, the **line item value** also increases. This shows a **direct relationship** between the two.
# -  **Wide Spread at Higher Quantities**: At higher quantities, the values vary more widely, indicating pricing or product differences.
# -  **Outliers Present**: A few points show extremely high values or quantities, which may need further investigation (e.g., bulk orders or data entry issues).
#
# ---
#
# ### **3. Can these insights help create a positive business impact?**
#
#  **Yes, they can help in several ways:**
#
# - **Forecasting revenue**: Understanding this relationship helps estimate total value based on quantity.
# - **Inventory planning**: Higher quantity orders may need better stock and logistics preparation.
# - **Customer segmentation**: High-value orders can identify key customers for special attention.
#
# ---
#
# ### **Any risks or possible negative impacts?**
#
#  **Yes, if not managed carefully:**
#
# - **Outliers might skew decisions**: Extremely large orders could mislead averages or projections.
# - **Assumption of linearity**: The relationship may not always be linear – bulk pricing, discounts, or promotions can alter the trend.
# - **Ignoring product types**: Different product categories could have different value-to-quantity ratios.

# %%
# Total Line Item Value by Vendor
vendor_value = df.groupby('Vendor')['Line Item Value'].sum().nlargest(10)
vendor_value.plot(kind='barh', figsize=(14, 6), color='purple')
plt.title('Top 10 Vendors by Line Item Value')
plt.xlabel('Total Line Item Value (USD)')
plt.ylabel('Vendor')
plt.show()

# %% [markdown]
# ### **1. Why was this chart chosen?**
#
# A **horizontal bar chart** is ideal to display **categorical data with large names (vendor names)** and compare their **total contribution** in terms of **line item value (USD)**. It clearly shows the top vendors and their impact.
#
# ---
#
# ### **2. What are the insights from the cht?**
#
# - 🏆 **SCMS from RDC dominates**: This vendor has by far the highest total line item value, making it the biggest contributor to
#    prorement.
# - 📊 **Huge gap** between top vendor and others: The rest of the vendors show significantly lower values, indicating **vendor con
#   cenation**.
# - 📈 **Top 3 vendors contribute the most**: After SCMS, **Organics Ltd.** and **Aurobindo Pharma** have the next highest contributions.
#
# ---
#
# ### **3. Can these insights help create a positive buiness impact?**
#
# ✅ **Yes, here’s how:**
#
# - **Supplier relationship management**: Businesses can prioritize maintaining strong ties with top vendors like and
#     reliability
#   terms and reliability.
# - **Spend analysis**: Helps track where the majority of funds are going and if those vendors are deli
# vering value for money.
# - **Risk management**: Identifies dependency on a single vendor (SCMS) and may prompt businesses to diversify suppliers to reduce risk.
#
# ---
#
# ### **Any risks or poible negative impacts?**
#
# ⚠️ **Yes, some risks to be aware of:**
#
# - **Vendor dependency**: Over-reliance on one vendor like SCMS can lead to operational risks if that vendor fails to deliver or raises prices.
# - **Lack of competition**: If one vendor dominates, it may reduce negotiation power and lead to higher costs.
# - **Neglecting smaller vendors**: Other vendors might have competitive offerings or more fle
#   is turned into a summary slide or PDF!

# %% [markdown]
# # Delivery Time Analysis

# %%
# Convert dates
df['Scheduled Delivery Date'] = pd.to_datetime(df['Scheduled Delivery Date'], errors='coerce')
df['Delivered to Client Date'] = pd.to_datetime(df['Delivered to Client Date'], errors='coerce')

# Calculate Delivery Time in days
df['Delivery Time'] = (df['Delivered to Client Date'] - df['Scheduled Delivery Date']).dt.days

# Filter out negative delivery times (if needed)
df = df[df['Delivery Time'] >= 0]

# Plot the data
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='Scheduled Delivery Date', y='Delivery Time')
plt.title('Delivery Time vs Scheduled Delivery Date')
plt.xlabel('Scheduled Delivery Date')
plt.ylabel('Delivery Time (Days)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### **1. Why was this chart chosen?**
#
# A **line/bar time series chart** is ideal for visualizing **delivery performance over time**. It helps track trends, spikes, and patterns in delivery delays across multiple years.
#
# ---
#
# ### **2. What are the insights from the chart?**
#
# -  **Rising delivery delays (2010–2014)**: There's a noticeable increase in delivery time starting around 2010, peaking heavily between **2011 and 2014**.
# -  **Delivery spikes in 2013–2014**: A few extreme spikes (over **150 days**) suggest **major delivery issues or exceptional cases** during that period.
# -  **Improved consistency post-2014**: After 2014, delivery times appear to stabilize and reduce, indicating **operational improvement** or better vendor management.
#
# ---
#
# ### **3. Can these insights help create a positive business impact?**
#
#  **Yes, potential positive impacts include:**
#
# - **Process improvement**: Identifying timeframes with poor delivery performance helps investigate root causes and improve supply chain efficiency.
# - **Vendor accountability**: Historical delivery trends help assess which vendors consistently deliver on time or cause delays.
# - **Forecasting and planning**: Businesses can better plan future deliveries and inventory based on past trends.
#
# ---
#
# ### **Any risks or negative insights?**
#
#  **Yes, a few concerns:**
#
# - **Unpredictable delays**: High variability and extreme delays may lead to stockouts, lost sales, or customer dissatisfaction.
# - **Lack of standardization**: Inconsistent delivery performance could point to systemic issues in logistics, customs, or vendor coordination.
# - **Historical issues unresolved**: If the spikes were never addressed, they may repeat in the future unless corrective actions were taken.

# %%
# Top 10 Brands by Line Item Value
top_brands = df.groupby('Brand')['Line Item Value'].sum().nlargest(10)
top_brands.plot(kind='bar', figsize=(10, 6), color='brown')
plt.title('Top 10 Brands by Line Item Value')
plt.xlabel('Brand')
plt.ylabel('Total Line Item Value (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### **1. Why was this chart chosen?**
#
# A **bar chart** is ideal for showing **comparisons in total line item value** among the top 10 brands. It clearly highlights which brands contribute the most to procurement spending.
#
# ---
#
# ### **2. What are the insights from the chart?**
#
# -  **Generic dominates**: The "Generic" brand has by far the **highest line item value**, over **$700 million**, indicating strong preference
#      or volume of purchase.
# -  **Determine ranks second**: With a significantly lower but still notable value (~$150 million), Determine is the **top proprietary brand**.
# -  **Steep drop-off**: After the top two, the remaining brands have much smaller shares, with brands like Aluvia, Truvada, and Uni-Gold
#      contributing modestly.
# -  **Specialized brands** like Atripla and Colloidal Gold appear, but with much lower total values.
#
# ---
#
# ### **3. Can these insights help create a positive business impact?**
#
#  **Yes, in multiple ways:**
#
# - **Cost efficiency**: Heavy use of generic brands suggests a **focus on cost-effective procurement**.
# - **Brand analysis**: Helps identify **top-performing or high-demand brands**, aiding supplier negotiations or inventory planning.
# - **Strategic sourcing**: Insights into brand preferences guide **long-term contracts**, bulk orders, or diversification strategies.
#
# ---
#
# ### **Any risks or negative insights?**
#
#  **Yes, a few to consider:**
#
# - **Overdependence on generics**: While cost-effective, it may introduce **quality or supply risk** if sourcing isn't diversified.
# - **Neglecting innovation**: Focus on lower-cost brands could mean missing out on **newer, more effective products**.
# - **Sudden demand changes**: If high-value brands fall out of favor or face shortages, it could **impact operations**.

# %%
# Distribution of Freight Cost (USD) by Product Group
plt.figure(figsize=(12, 6))
sns.violinplot(x='Product Group', y='Freight Cost (USD)', data=df, hue='Product Group', palette='Set3', legend=False)

# Set title and labels
plt.title('Distribution of Freight Cost (USD) by Product Group', fontsize=14)
plt.xlabel('Product Group', fontsize=12)
plt.ylabel('Freight Cost (USD)', fontsize=12)

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### **1. Why was this chart chosen?**
#
# A **violin plot** is ideal to visualize both the **distribution shape and spread** of freight costs across different product groups. It gives a clearer picture of **variability, density, and outliers** in cost data.
#
# ---
#
# ### **2. What are the insights from the chart?**
#
# -  **HRDT** (High Range Diagnostic Test kits) has the **widest spread** with extreme outliers reaching nearly **$300,000** — indicating
#    **high variability and occasional spikes** in freight costs.
#
# -  **ARV** (Antiretroviral) also shows large cost variability with outliers beyond **$150,000**, suggesting **some expensive or long-distance
#    shipments**.
#
# -  **MRDT**, **ACT**, and **ANTM** groups show **more consistent and tighter distributions**, especially **MRDT**, which has the **lowest and
#    most stable freight costs**.
#
# -  The **bulk of shipments** in all groups fall within a relatively **narrow cost range**, but the tails show **occasional large
#    expenditures**.
#
# ---
#
# ### **3. Can these insights help create a positive business impact?**
#
#  **Yes, absolutely:**
#
# - **Cost optimization**: HRDT and ARV groups may need **route audits or logistics reviews** to identify and control high-cost shipments.
# - **Forecasting accuracy**: Understanding typical cost spreads helps in **budget planning** and setting **realistic freight cost expectations**.
# - **Vendor negotiations**: Helps in **contract discussions** with freight providers to address high variability.
#
# ---
#
# ### **Any risks or negative insights?**
#
#  **Yes, some potential concerns:**
#
# - **Unpredictable costs**: High spread in HRDT/ARV makes **cost planning uncertain**.
# - **Operational inefficiencies**: May indicate **last-minute shipments or poor route optimization**.
# - **Outliers may hide issues**: Some extremely high costs could be tied to **emergency deliveries or supplier issues**.

# %%
# Correlation Between Cost Metrics
cost_metrics = df[['Line Item Value', 'Freight Cost (USD)', 'Weight (Kilograms)', 'Unit Price']].copy()
cost_metrics = cost_metrics.dropna()  # Drop rows with missing data

corr = cost_metrics.corr()

plt.figure(figsize=(9, 6))
sns.heatmap(corr, annot=True, cmap="Blues", linewidths=0.5)
plt.title("Correlation Matrix: Cost and Weight")
plt.tight_layout()
plt.show()

# %% [markdown]
# **
#
# ### **1. Why was this chart chosen?**
#
# A **correlation matrix** provides a concise summary of the **linear relationships** between key variables such as **cost, weight, unit price, and item value**. It helps identify which factors are likely to move together — a critical input for **cost modeling and operational decision-making**.
#
# ---
#
# ### **2. What are the insights from the chart?**
#
# - **Weight** has a **moderate positive correlation** with both **Line Item Value (0.38)** and **Freight Cost (0.30)**, suggesting **heavier items tend to cost more and are more valuable**.
# - **Freight Cost** also correlates with **Line Item Value (0.36)**, indicating **more expensive items incur higher freight costs**.
# - **Unit Price** shows almost **no correlation** with any variable, suggesting **unit price has minimal influence on weight or logistics cost**.
#
# ---
#
# ### **3. Can these insights help create a positive business impact?**
#
# **Yes:**
#
# - **Strategic pricing and cost control**: Understanding that **weight** and **value** drive cost helps in **forecasting freight budgets**.
# - **Inventory and product planning**: Helps identify product types that might be **expensive to ship**, guiding **inventory optimization**.
# - **Data-driven logistics decisions**: Encourages focusing on **high-weight, high-value items** for cost-saving measures.
#
# ---
#
# ### **Any risks or negative insights?**
#
# **Yes:**
#
# - **Unit Price’s lack of correlation** might signal **poor alignment between product pricing and logistics cost**, which could mean **profit leakage**.
# - **Moderate correlations** imply **other hidden variables** (like urgency or destination) may also be influencing freigslide format — I can help build the text for PowerPoint or Google Slides too.

# %%
# Freight Cost vs. Weight
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Weight (Kilograms)', y='Freight Cost (USD)', hue='Shipment Mode')
plt.title("Freight Cost vs. Weight by Shipment Mode")
plt.xlabel("Weight (kg)")
plt.ylabel("Freight Cost (USD)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **1. Why was this chart chosen?**
#
# This **scatter plot with color-coded shipment modes** was chosen to explore the **relationship between freight cost and shipment weight**, while also highlighting **how shipment mode affects this relationship**. It’s excellent for detecting **cost clusters, inefficiencies, and outliers by transport type**.
#
# ---
#
# ### **2. What are the insights from the chart?**
#
# - **Air shipments** (blue) are **consistently expensive**, even for **lower weights** — indicating **high per-kg cost**.
# - **Truck** mode (orange) handles **moderate weights with balanced cost**, making it a **cost-effective choice for mid-range loads**.
# - **Ocean shipments** (red) are **rare** but show **low cost for higher weights**, suggesting they’re optimal for **bulk shipments**.
# - **Air Charter** (green) appears infrequently, with **a few high-cost, high-weight points**, likely representing **urgent or specialized deliveries**.
# - Majority of data points are clustered in the **lower weight/cost zone**, hinting that **most shipments are small to mid-size**.
#
# ---
#
# ### **3. Can these insights help create a positive business impact?**
#
# **Definitely:**
#
# - **Shipping strategy improvement**: Businesses can **switch heavy shipments to Ocean or Truck** to reduce costs.
# - **Air mode audits**: Identifying **costly Air shipments for low weights** allows for **route reviews and mode reconsideration**.
# - **Better shipment planning**: Understanding cost-weight dynamics supports **budgeting, vendor negotiation, and cost allocation**.
#
# ---
#
# ### **Any risks or negative insights?**
#
# **Yes:**
#
# - **Over-reliance on Air** for light shipments is a major cost driver — potentially reducing margins.
# - **High outliers** in Air and Truck could suggest **last-minute or mismanaged shipments**.
# - **Inefficient mode choices** (e.g., using Air when Ocean is suitable) may stem from **poor logistics coordination** or **lack of advanced planning**.

# %% [markdown]
# # 🎯 **5. Solution to Business Objective**
#
# To achieve the goal of **optimizing procurement, minimizing logistics costs, and enhancing supplier performance**, the following strategic actions are recommended:
#
# --
#
# ### ✅ **1. Prioritize High-Value Vendors & Brands**
# - Focus on **strategic collaboration** with key vendors like **SCMS (RDC)** and top brands such as **Generic** and **Determine**.
# - These vendors represent the **largest share of procurement spend** — negotiating **bulk deals, better payment terms, and faster delivery** will yield **maximum cost-saving impact**
#
# ---
#
# ### 🚚 **2. Optimize Delivery Time**
# - Historical data (especially between **2011–2013**) shows **inconsistent delivery times**.
# - Conduct a **root cause analysis** (e.g., political disruptions, supplier delays).
# - Establish a **Supplier Performance Scorecard** to monitor and improve **on-time delivery meics**.
#
# ---
#
# ### 💸 **3. Control Freight Costs by Product Group**
# - **HRDT** and **ARV** categories show **high variability and outlier freight costs**.
#   - Consolidate smaller shipments to reduce per-unit cost.
#   - Leverage **route optimization tools** for better shipment planning.
#   - Define **cost ceilings or freight-to-value thresholds** to flag expensive shipments early.
#   - Reevaluate supplier contracts for those with **inefficient freht practices**.
#
# ---
#
# ### 📦 **4. Improve Inventory Planning**
# - Use insights from delivery and procurement data to **predict demand more accurately**.
# - Reduce reliance on **costly emergency shipments** by maintaining **optimal reorder points**.
# - Adopt **forecasting and planning systems** (e.g., predictive analytics) to align sck levels with demand.
#
# ---
#
# ### 📊 **5. Implement Dashboards for Ongoing Monitoring**
# - Set up **interactive Power BI dashboards** to track:
#   - Freight cost trends by product, supplier, and route
#   - Vendor reliability and performance KPIs
#   - Brand-level procurement spend
# - Enable **real-time alerts** for outliers and **data-driven ecision-making** at every level.
# ---
#
# ### ✅ **Expected Business Impact**
# -  **Reduced logistics and procurement costs**
# - ⏱️ **ster and more reliable supplier performance**
# - 📦 **Imoved inventory availability and stock health**
# - 🔍 **Prctive planning with accurate demand forecasts**
# - 🤝 **Strengthenesting analysis — I can help with layout suggestions too!

# %% [markdown]
# ## ✅ **Conclusion**
#
# The analysis provides valuable insights into the client’s **procurement and supply chain performance**, revealing key opportunities for cost savings and operational improvements. By identifying the **top vendors and brands by total procurement spend**, evaluating **delivery performance over time**, and analyzing **freight cost variations across product groups**, we highlight critical areas for strategic focus.
#
# Additionally, deep-dives into **freight cost distributions** reveal that products like **HRDT and ARV** exhibit **high variability and extreme cost outliers**, pointing to inefficiencies in shipment planning and vendor freight handling. Optimizing these shipments through consolidation and smarter logistics choices can yield significant cost reductions.
#
# Furthermore, the **scatter analysis of freight cost versus weight by shipment mode** uncovers an overreliance on **Air shipments**, often for lighter weights, leading to inflated costs. This suggests a strong case for **mode optimization**, such as shifting non-urgent or high-weight shipments to **Truck or Ocean**, which are more cost-effective.
#
# Together, these insights empower the organization to:
# - Enhance **vendor management** and **negotiate smarter contracts**
# - Improve **delivery reliability** and **inventory forecasting**
# - Reduce **freight cost leakages** through **shipment mode optimization**
# - Support **data-driven procurement strategies**
#
# By acting on these findings, the client can drive **greater operational efficiency**, **reduce total costs**, and align procurement practices more closely with **long-term b a presentation slide!

# %% [markdown]
# # **END OF THE ANALYSIS**
